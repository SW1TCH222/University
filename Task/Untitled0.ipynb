# %% [markdown]
# <a href="https://colab.research.google.com/github/SW1TCH222/University/blob/main/Task/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Print('Hello world')
Print('Hello Miigaik')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1634/3750153022.py in <cell line: 0>()
# ----> 1 Print('Hello world')
#       2 Print('Hello Miigaik')
#
# NameError: name 'Print' is not defined
